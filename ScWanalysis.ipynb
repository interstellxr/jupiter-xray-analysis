# %%
import oda_api.token 
import logging
import numpy as np
from oda_api.api import DispatcherAPI
from oda_api.plot_tools import OdaImage, OdaLightCurve, OdaSpectrum
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.wcs import WCS
from matplotlib.patches import Circle
from astropy.time import Time

# %%
# token = ''
# token = getpass.getpass('Insert the token')
token = oda_api.token.discover_token() # get token stored locally

# %%
logging.getLogger().setLevel(logging.INFO) # WARNING, INFO or DEBUG
logging.getLogger('oda_api').addHandler(logging.StreamHandler())

# %% [markdown]
# Import the ScWs from the saved file.

# %%
scw_ids = []
scw_versions = []
scw_start_times = []
scw_end_times = []
jupiter_ra = []
jupiter_dec = []

with open("2004-01-01_2024-01-01.txt", "r") as f:
    next(f)
    for line in f:
        parts = line.strip().split(", ")
        scw_ids.append(parts[0])
        scw_versions.append(parts[1])
        scw_start_times.append(float(parts[2]))  
        scw_end_times.append(float(parts[3]))  
        jupiter_ra.append(float(parts[4]))  
        jupiter_dec.append(float(parts[5]))

# %% [markdown]
# Add IDs and versions together to make correctly formatted ScWs, and compute durations of the ScW observations.

# %%
scw_list = [id + "." + ver for id, ver in zip(scw_ids, scw_versions)]
scw_durations = [(end - start)*24*60 for start, end in zip(scw_start_times, scw_end_times)]
print(scw_list)
print(scw_durations)
print([Time(start, format='mjd').isot for start in scw_start_times])
print("Max duration in minutes:", np.max(scw_durations), "at position", np.argmax(scw_durations))
# Out:
# ['026601100010.001', '026601110010.001', '026700000210.001', '026700000230.001', '043200640010.001', '043200650010.001', '091700010010.001', '091700020010.001', '106300180010.001', '106300190010.001', '112600220010.001', '112600230010.001', '124200010010.001', '124200020010.001', '169500010010.001', '169500020010.001', '230200070010.001', '230200080010.001', '230200090010.001', '230200160010.001', '230200170010.001', '230200180010.001', '230200470010.001', '230200480010.001', '230200490010.001', '230200550010.001', '230200560010.001', '230200570010.001', '230200570020.001', '236600410010.001', '236600420010.001', '236600440010.001', '236600450010.001', '236600460010.001', '236600470010.001', '236600480010.001', '236600490010.001', '236600500010.001', '236600510010.001', '236600520010.001', '236600530010.001', '236600540010.001', '236600550010.001', '236600560010.001', '236600570010.001', '236600580010.001', '236600590010.001', '236600600010.001', '236600610010.001', '236600620010.001', '236700010010.001', '236700020010.001', '236700030010.001', '236700040010.001', '236700050010.001', '236700060010.001', '236700070010.001', '236700080010.001', '236700090010.001', '236700100010.001', '236700110010.001', '236700120010.001', '236700130010.001', '236700140010.001', '236700150010.001', '236700160010.001', '236700170010.001', '236700180010.001', '236700190010.001', '236700200010.001', '236700210010.001', '236700220010.001', '236700250010.001', '236800110010.001', '236800120010.001', '236800130010.001', '236800140010.001', '236800160010.001', '236800170010.001', '236800180010.001', '236800190010.001', '236800200010.001', '236800210010.001', '236900030010.001', '236900040010.001', '236900050010.001', '236900060010.001', '236900070010.001', '236900080010.001', '236900090010.001', '236900100010.001', '236900110010.001', '236900120010.001', '237200010010.001', '237200020010.001', '237300010010.001', '237300020010.001', '
-29T05:10:22.194', '2006-04-29T05:22:09.195', '2011-06-28T10:40:48.998', '2011-06-28T10:52:36.998', '2012-01-03T03:24:40.594', '2012-01-03T03:39:54.595', '2012-12-14T11:04:08.379', '2012-12-14T11:19:25.380', '2016-06-05T01:14:24.654', '2016-06-05T01:25:45.654', '2016-06-26T17:49:59.816', '2016-06-26T18:01:51.817', '2020-11-26T22:58:31.199', '2020-11-26T23:10:19.199', '2020-11-27T00:07:35.201', '2020-11-27T07:47:35.218', '2020-11-28T16:28:38.287', '2020-11-29T00:08:22.304', '2020-11-29T01:05:38.306', '2020-11-29T02:04:29.308', '2021-05-17T17:18:09.192', '2021-05-17T18:08:09.194', '2021-05-17T19:50:18.198', '2021-05-17T20:41:34.200', '2021-05-17T21:32:15.201', '2021-05-17T22:23:15.203', '2021-05-17T23:14:14.205', '2021-05-18T00:05:12.207', '2021-05-18T00:55:54.209', '2021-05-18T01:46:38.211', '2021-05-18T02:37:21.213', '2021-05-18T03:28:22.215', '2021-05-18T04:19:03.217', '2021-05-18T05:09:45.218', '2021-05-18T06:00:46.220', '2021-05-18T06:51:27.222', '20 ...
# Max duration in minutes: 150.28342847828753 at position 198

# %% [markdown]
# Query the ODA API.

# %%
disp = DispatcherAPI(url="https://www.astro.unige.ch/mmoda/dispatch-data", instrument="mock")

list_position = 17 # 3, 198, 17

par_dict = {
"E1_keV": "15", # 15
"E2_keV": "30", # 30
"T_format": "isot",
"detection_threshold": "5", # for images
# "time_bin": "70", # for light curves
"instrument": "isgri",
# "osa_version": "OSA11.2",
"product": "isgri_image", # isgri_image or isgri_lc or isgri_spectrum
"product_type": "Real",
"scw_list": [scw_list[list_position]],
'token': token
}

data_collection = disp.get_product(**par_dict)
data_collection.show()
# Out:
# found token in TokenLocation.FILE_CUR_DIR your token payload: {
#     "email": "hucklethums@icloud.com",
#     "exp": 1741779981,
#     "name": "interstellxr",
#     "roles": "authenticated user, public-pool-hpc",
#     "sub": "hucklethums@icloud.com"
# }
# token expires in 189.1 h
# discovered token in environment
# please beware that by default, in a typical setup, oda_api will not output much. To learn how to increase the verbosity, please refer to the documentation: https://oda-api.readthedocs.io/en/latest/user_guide/ScienceWindowList.html?highlight=logging#Let's-get-some-logging .
# To disable this message you can pass `.get_product(..., silent=True)`
# - waiting for remote response (since 2025-03-04 15:39:44), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#
# ... query status prepared => submitted
# ... assigned job id: e84691cbdddd80c2
#  | the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 21 seconds (21/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:40:07), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  / the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 23 seconds (11/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:40:09), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  - the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 27 seconds (8.4/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:40:12), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  \ the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 32 seconds (7.5/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:40:18), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  | the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 37 seconds (6.8/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:40:23), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  / the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 43 seconds (6.4/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:40:29), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  - the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 49 seconds (6.3/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:40:35), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  \ the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 55 seconds (6.1/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:40:41), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  | the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 59 seconds (5.8/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:40:45), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  / the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 65 seconds (5.7/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:40:51), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  - the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 69 seconds (5.4/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:40:55), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  \ the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 74 seconds (5.3/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:41:00), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  | the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 80 seconds (5.3/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:41:06), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  / the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 85 seconds (5.2/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:41:10), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  - the job is working remotely, please wait status=submitted job_id=e84691cb in 0 messages since 88 seconds (5/21); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-04 15:41:14), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#
# ... query status submitted => progress
#  \ the job is working remotely, please wait status=progress job_id=e84691cb in 1 messages since 98 seconds (5.3/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:41:24), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  | the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 115 seconds (5.9/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:41:41), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  / the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 121 seconds (5.8/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:41:47), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  - the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 126 seconds (5.7/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:41:52), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  \ the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 131 seconds (5.7/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:41:57), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  | the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 136 seconds (5.6/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:42:02), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  / the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 140 seconds (5.4/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:42:06), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  - the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 146 seconds (5.4/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:42:12), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  \ the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 151 seconds (5.4/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:42:17), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  | the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 156 seconds (5.3/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:42:22), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  / the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 159 seconds (5.2/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:42:25), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  - the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 165 seconds (5.2/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:42:31), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  \ the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 168 seconds (5.1/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:42:34), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  | the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 175 seconds (5.1/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:42:41), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  / the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 182 seconds (5.1/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:42:48), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  - the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 187 seconds (5.1/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:42:53), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  \ the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 193 seconds (5.1/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:42:59), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  | the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 198 seconds (5/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:43:04), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  / the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 202 seconds (5/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:43:08), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  - the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 206 seconds (4.9/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:43:12), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  \ the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 212 seconds (4.9/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:43:18), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  | the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 218 seconds (4.9/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:43:24), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  / the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 222 seconds (4.9/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:43:27), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  - the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 226 seconds (4.8/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:43:32), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  \ the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 230 seconds (4.8/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:43:35), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  | the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 235 seconds (4.8/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:43:41), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  / the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 240 seconds (4.8/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:43:46), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  - the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 246 seconds (4.8/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:43:52), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  \ the job is working remotely, please wait status=progress job_id=e84691cb in 2 messages since 251 seconds (4.7/21); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-04 15:43:57), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  | the job is working remotely, please wait status=progress job_id=e84691cb in 3 messages since 258 seconds (4.8/21); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 230200080010.001
# - waiting for remote response (since 2025-03-04 15:44:04), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  / the job is working remotely, please wait status=progress job_id=e84691cb in 3 messages since 261 seconds (4.7/21); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 230200080010.001
# - waiting for remote response (since 2025-03-04 15:44:07), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  - the job is working remotely, please wait status=progress job_id=e84691cb in 3 messages since 268 seconds (4.7/21); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 230200080010.001
# - waiting for remote response (since 2025-03-04 15:44:14), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  \ the job is working remotely, please wait status=progress job_id=e84691cb in 3 messages since 273 seconds (4.7/21); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 230200080010.001
# - waiting for remote response (since 2025-03-04 15:44:19), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  | the job is working remotely, please wait status=progress job_id=e84691cb in 3 messages since 277 seconds (4.7/21); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 230200080010.001
# - waiting for remote response (since 2025-03-04 15:44:23), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  / the job is working remotely, please wait status=progress job_id=e84691cb in 3 messages since 284 seconds (4.7/21); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 230200080010.001
# - waiting for remote response (since 2025-03-04 15:44:30), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: DH3527QWRH508GCC job: e84691cbdddd80c2
#  - the job is working remotely, please wait status=progress job_id=e84691cb in 3 messages since
please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis

# %% [markdown]
# IMAGE

# %%
data_collection.mosaic_image_0_mosaic.show()
print(data_collection.mosaic_image_0_mosaic.show_meta())
# Out:
# ------------------------------
# name: mosaic_image
# meta_data dict_keys(['product', 'instrument', 'src_name', 'query_parameters'])
# number of data units 6
# ------------------------------
# data uniti 0 ,name: PRIMARY
# data uniti 1 ,name: GROUPING
# data uniti 2 ,name: ISGR-MOSA-IMA
# data uniti 3 ,name: ISGR-MOSA-IMA
# data uniti 4 ,name: ISGR-MOSA-IMA
# data uniti 5 ,name: ISGR-MOSA-IMA
# ------------------------------
# product : mosaic
# instrument : isgri
# src_name :
# query_parameters : None
# ------------------------------
# None

# %%
im=OdaImage(data_collection)
_ = im.show()
im.write_fits(f"{scw_ids[list_position]}"+f".{scw_versions[list_position]}")
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATEREF to '2000-01-01' from MJDREF.
# Set MJD-OBS to 53359.426435 from DATE-OBS.
# Set MJD-END to 53359.449363 from DATE-END'. [astropy.wcs.wcs]
# /home/hthums/micromamba/envs/jupiter_xray/lib/python3.9/site-packages/oda_api/plot_tools.py:101: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# './026700000230.001mosaic.fits'

# %%
from astropy.wcs import WCS
from matplotlib.patches import Circle

fits_file = f"{scw_list[list_position]}"+"mosaic.fits"

pick = 2 # 2 for image, 3 for variance, 4 for significance and 5 for exposure map

# Jupiter
ra_deg = jupiter_ra[list_position]
dec_deg = jupiter_dec[list_position]

with fits.open(fits_file) as hdul:
    hdul.info()
    image_data = hdul[pick].data 
    print("\n")
    print(repr(hdul[pick].header))
    print("\n")
    wcs = WCS(hdul[pick].header)  
    CD1 = np.abs(hdul[pick].header["CD1_1"])

x, y = wcs.all_world2pix(ra_deg, dec_deg, 1)

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection=wcs)
im = ax.imshow(np.log10(image_data), cmap='plasma', origin='lower')

ax.set_xlabel('RA')
ax.set_ylabel('DEC')

pixel_scale = CD1 * 3600  # pixel size in arcseconds (|CD1_1| from fits header)
circle_radius_pixels = 30 * 40 / pixel_scale / 2  # radius in pixels (30 times Jupiter's apparent size which is ~ 40")

circle = Circle((x, y), circle_radius_pixels, edgecolor='black', facecolor='none', lw = 0.5)
ax.add_patch(circle)

title = ""
if pick == 2:
    title = "Intensity"
elif pick == 3:
    title = "Variance"
elif pick == 4:
    title = "Significance"
elif pick == 5:
    title = "Exposure"

plt.title(title+" map")
plt.colorbar(im, label="Intensity")

ax.annotate(
    text="Jupiter (30x Rj)", 
    xy=(x, y),  
    xytext=(x - 100, y + 150),
    arrowprops=dict(arrowstyle="->", color="black", lw=0.5),
    fontsize=11,
    color="black"
)

plt.savefig(f"{scw_list[list_position]}"+"_"+f"{title}.pdf", format='pdf', bbox_inches='tight')
# Out:
# Filename: 026700000230.001mosaic.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  GROUPING      1 BinTableHDU     82   4R x 16C   [8A, 32A, 1J, 1J, 256A, 3A, 32A, 1I, 1I, 1E, 1E, 1E, 1D, 1D, 1D, 1D]
#   2  ISGR-MOSA-IMA    1 ImageHDU        67   (543, 543)   float32
#   3  ISGR-MOSA-IMA    2 ImageHDU        67   (543, 543)   float32
#   4  ISGR-MOSA-IMA    3 ImageHDU        67   (543, 543)   float32
#   5  ISGR-MOSA-IMA    4 ImageHDU        67   (543, 543)   float32
#
#
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  543
# NAXIS2  =                  543
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# BASETYPE= 'DAL_ARRAY'
# BUNIT   = 'counts/sec'
# CD1_1   =  -0.0822862539155913
# CD1_2   =                  0.0
# CD2_1   =                  0.0
# CD2_2   =   0.0822862539155913
# CHANMAX =                   30
# CHANMIN =                   15
# CHANTYPE= 'PI      '
# CHECKSUM= 'ZV5ldS4iZS4ibS4i'
# COMMENT STAMP :
# CONFIGUR= 'latest_osa_sw_2015-11-10T03:50:02'
# CREATOR = 'ii_skyimage 5.4.4'
# CRPIX1  =                272.0
# CRPIX2  =                272.0
# CRVAL1  =     154.472244262695
# CRVAL2  =     5.13706064224243
# CTYPE1  = 'RA---TAN'
# CTYPE2  = 'DEC--TAN'
# CUNIT1  = 'deg     '
# CUNIT2  = 'deg     '
# DATASUM = '3015745277'
# DATE    = '2025-03-03T12:56:08'
# DATE-END= '2004-12-20T10:47:05'
# DATE-OBS= '2004-12-20T10:14:04'
# DEADC   =    0.746276423742573
# DETNAM  = 'ISGRI   '
# EQUINOX =               2000.0
# EXTNAME = 'ISGR-MOSA-IMA'
# EXTREL  = '7.4     '
# EXTVER  =                    1
# E_MAX   =                 30.0
# E_MEAN  =                 22.5
# E_MIN   =                 15.0
# GRPID1  =                    1
# HDUCLAS1= 'IMAGE   '
# HDUCLASS= 'OGIP    '
# HDUDOC  = 'ISDC-IBIS ICD'
# HDUVERS = '1.1.0   '
# IMATYPE = 'INTENSITY'
# INSTRUME= 'IBIS    '
# ISDCLEVL= 'IMA     '
# LATPOLE =                    0
# LONGPOLE=                  180
# MJDREF  =              51544.0
# MOSASPR =                    1
# OGID    = 'String  '
# ONTIME  =     1805.81726074219
# ORIGIN  = 'ISDC    '
# RADECSYS= 'FK5     '
# STAMP   = '2025-03-03T12:56:08 ii_skyimage 5.4.4'
# TELAPSE =               1813.0
# TELESCOP= 'INTEGRAL'
# TFIRST  =     1815.42725171659
# TIMEREF = 'LOCAL   '
# TIMESYS = 'TT      '
# TIMEUNIT= 'd       '
# TLAST   =     1815.44824285814
# TSTART  =     1815.42718597238
# TSTOP   =      1815.4501142253
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATEREF to '2000-01-01' from MJDREF.
# Set MJD-OBS to 53359.426435 from DATE-OBS.
# Set MJD-END to 53359.449363 from DATE-END'. [astropy.wcs.wcs]
# /tmp/ipykernel_1108/3110708561.py:24: RuntimeWarning: divide by zero encountered in log10
#   im = ax.imshow(np.log10(image_data), cmap='plasma', origin='lower')
# /tmp/ipykernel_1108/3110708561.py:24: RuntimeWarning: invalid value encountered in log10
#   im = ax.imshow(np.log10(image_data), cmap='plasma', origin='lower')
