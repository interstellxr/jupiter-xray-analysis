# %%
import oda_api.token 
import logging
import numpy as np
from oda_api.api import DispatcherAPI
from oda_api.plot_tools import OdaImage, OdaLightCurve, OdaSpectrum
import matplotlib.pyplot as plt
import astroquery.heasarc
from astropy.wcs import WCS
from astropy.io import fits
from astroquery.simbad import Simbad
from astropy import coordinates as coord
from astropy.coordinates import SkyCoord
from astropy.time import Time
from matplotlib.patches import Circle
from astroquery.jplhorizons import Horizons
import pandas as pd
import astropy.units as u
import json

# %%
logging.getLogger().setLevel(logging.INFO)
logging.getLogger('oda_api').addHandler(logging.StreamHandler())

# %% [markdown]
# Load the ScWs

# %%
scws = []
scw_start_times = []
scw_end_times = []

with open("../data/Crab-ScWs.txt", "r") as f:
    next(f)
    for line in f:
        parts = line.strip().split(", ")
        scws.append(parts[0])
        scw_start_times.append(float(parts[1]))  
        scw_end_times.append(float(parts[2]))  

unique_sorted_data = {}
for scw, start, end in sorted(zip(scws, scw_start_times, scw_end_times), key=lambda x: x[0]):
    if scw not in unique_sorted_data:  
        unique_sorted_data[scw] = (scw, start, end)

scws, scw_start_times, scw_end_times = map(list, zip(*unique_sorted_data.values()))

# %% [markdown]
# Pick a random ScW.

# %%
np.random.seed = 999
pick = np.random.randint(len(scws))
scw_pick = scws[pick]
start_pick = scw_start_times[pick]
end_pick = scw_end_times[pick]

# %% [markdown]
# ## QUERYING

# %%
disp = DispatcherAPI(url="https://www.astro.unige.ch/mmoda/dispatch-data", instrument="mock")

crab = SkyCoord.from_name("Crab")
ra = crab.ra.deg
dec = crab.dec.deg

par_dict = {
    "RA": ra,
    "DEC": dec,
    "E1_keV": "15",
    "E2_keV": "30",
    "T_format": "mjd",
    'T1': start_pick,
    'T2': end_pick,
    "detection_threshold": "5",
    "instrument": "isgri",
    "osa_version": "OSA11.2",
    "product": "isgri_image",
    "product_type": "Real",
    "scw_list": [scw_pick],
    'token': oda_api.token.discover_token()
}

data_collection = disp.get_product(**par_dict)
data_collection.show()
# Out:
# found token in TokenLocation.FILE_CUR_DIR your token payload: {
#     "email": "hucklethums@icloud.com",
#     "exp": 1742905994,
#     "name": "interstellxr",
#     "roles": "authenticated user, public-pool-hpc",
#     "sub": "hucklethums@icloud.com"
# }
# found token in TokenLocation.FILE_CUR_DIR your token payload: {
#     "email": "hucklethums@icloud.com",
#     "exp": 1742905994,
#     "name": "interstellxr",
#     "roles": "authenticated user, public-pool-hpc",
#     "sub": "hucklethums@icloud.com"
# }
# found token in TokenLocation.FILE_CUR_DIR your token payload: {
#     "email": "hucklethums@icloud.com",
#     "exp": 1742905994,
#     "name": "interstellxr",
#     "roles": "authenticated user, public-pool-hpc",
#     "sub": "hucklethums@icloud.com"
# }
# token expires in 236.4 h
# token expires in 236.4 h
# token expires in 236.4 h
# discovered token in environment
# discovered token in environment
# discovered token in environment
# found token in TokenLocation.FILE_CUR_DIR your token payload: {
#     "email": "hucklethums@icloud.com",
#     "exp": 1742905994,
#     "name": "interstellxr",
#     "roles": "authenticated user, public-pool-hpc",
#     "sub": "hucklethums@icloud.com"
# }
# found token in TokenLocation.FILE_CUR_DIR your token payload: {
#     "email": "hucklethums@icloud.com",
#     "exp": 1742905994,
#     "name": "interstellxr",
#     "roles": "authenticated user, public-pool-hpc",
#     "sub": "hucklethums@icloud.com"
# }
# found token in TokenLocation.FILE_CUR_DIR your token payload: {
#     "email": "hucklethums@icloud.com",
#     "exp": 1742905994,
#     "name": "interstellxr",
#     "roles": "authenticated user, public-pool-hpc",
#     "sub": "hucklethums@icloud.com"
# }
# token expires in 236.4 h
# token expires in 236.4 h
# token expires in 236.4 h
# please beware that by default, in a typical setup, oda_api will not output much. To learn how to increase the verbosity, please refer to the documentation: https://oda-api.readthedocs.io/en/latest/user_guide/ScienceWindowList.html?highlight=logging#Let's-get-some-logging .
# To disable this message you can pass `.get_product(..., silent=True)`
# please beware that by default, in a typical setup, oda_api will not output much. To learn how to increase the verbosity, please refer to the documentation: https://oda-api.readthedocs.io/en/latest/user_guide/ScienceWindowList.html?highlight=logging#Let's-get-some-logging .
# To disable this message you can pass `.get_product(..., silent=True)`
# please beware that by default, in a typical setup, oda_api will not output much. To learn how to increase the verbosity, please refer to the documentation: https://oda-api.readthedocs.io/en/latest/user_guide/ScienceWindowList.html?highlight=logging#Let's-get-some-logging .
# To disable this message you can pass `.get_product(..., silent=True)`
# - waiting for remote response (since 2025-03-15 17:08:06), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:08:06), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:08:06), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#
# ... query status prepared => submitted
#
# ... query status prepared => submitted
#
# ... query status prepared => submitted
# ... assigned job id: 6ce2c0755e724142
# ... assigned job id: 6ce2c0755e724142
# ... assigned job id: 6ce2c0755e724142
#  | the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 8 seconds (8.5/8.5); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  | the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 8 seconds (8.5/8.5); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  | the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 8 seconds (8.5/8.5); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-15 17:08:15), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:08:15), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:08:15), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  / the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 15 seconds (7.1/8.5); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  / the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 15 seconds (7.1/8.5); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  / the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 15 seconds (7.1/8.5); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-15 17:08:22), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:08:22), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:08:22), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  - the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 34 seconds (11/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  - the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 34 seconds (11/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  - the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 34 seconds (11/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-15 17:08:42), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:08:42), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:08:42), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  \ the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 40 seconds (9.2/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  \ the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 40 seconds (9.2/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  \ the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 40 seconds (9.2/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-15 17:08:47), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:08:47), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:08:47), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  | the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 45 seconds (8.2/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  | the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 45 seconds (8.2/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  | the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 45 seconds (8.2/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-15 17:08:52), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:08:52), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:08:52), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  / the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 51 seconds (7.7/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  / the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 51 seconds (7.7/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  / the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 51 seconds (7.7/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-15 17:08:58), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:08:58), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:08:58), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  - the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 57 seconds (7.3/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  - the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 57 seconds (7.3/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  - the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 57 seconds (7.3/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-15 17:09:04), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:04), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:04), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  \ the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 62 seconds (7/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  \ the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 62 seconds (7/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  \ the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 62 seconds (7/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-15 17:09:10), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:10), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:10), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  | the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 68 seconds (6.7/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  | the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 68 seconds (6.7/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  | the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 68 seconds (6.7/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-15 17:09:16), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:16), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:16), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  / the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 73 seconds (6.5/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  / the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 73 seconds (6.5/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
#  / the job is working remotely, please wait status=submitted job_id=6ce2c075 in 0 messages since 73 seconds (6.5/18); in 0 SCW so far; nodes (0): 0 computed 0 restored
# ...
# - waiting for remote response (since 2025-03-15 17:09:21), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:21), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:21), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#
# ... query status submitted => progress
#
# ... query status submitted => progress
#
# ... query status submitted => progress
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 1 messages since 82 seconds (6.6/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 1 messages since 82 seconds (6.6/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 1 messages since 82 seconds (6.6/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:09:30), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:30), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:30), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 90 seconds (6.6/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 90 seconds (6.6/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 90 seconds (6.6/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:09:38), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:38), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:38), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 100 seconds (6.8/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 100 seconds (6.8/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 100 seconds (6.8/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:09:47), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:47), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:47), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 109 seconds (6.9/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 109 seconds (6.9/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 109 seconds (6.9/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:09:56), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:56), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:09:56), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 120 seconds (7.1/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 120 seconds (7.1/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 120 seconds (7.1/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:10:07), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:10:07), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:10:07), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 125 seconds (6.9/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 125 seconds (6.9/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 125 seconds (6.9/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:10:13), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:10:13), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:10:13), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 135 seconds (7/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 135 seconds (7/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 135 seconds (7/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:10:22), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:10:22), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:10:22), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 142 seconds (7/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 142 seconds (7/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 142 seconds (7/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:10:30), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:10:30), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:10:30), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 150 seconds (7/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 150 seconds (7/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 150 seconds (7/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:10:38), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:10:38), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:10:38), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 161 seconds (7.1/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 161 seconds (7.1/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 161 seconds (7.1/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:10:48), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:10:48), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:10:48), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 170 seconds (7.2/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 170 seconds (7.2/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 170 seconds (7.2/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:10:57), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:10:57), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:10:57), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 178 seconds (7.2/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 178 seconds (7.2/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 178 seconds (7.2/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:11:06), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:11:06), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:11:06), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 183 seconds (7/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 183 seconds (7/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 183 seconds (7/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:11:11), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:11:11), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:11:11), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 202 seconds (7.5/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 202 seconds (7.5/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 202 seconds (7.5/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:11:29), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:11:29), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:11:29), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 207 seconds (7.3/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 207 seconds (7.3/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 207 seconds (7.3/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:11:34), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:11:34), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:11:34), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 215 seconds (7.3/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 215 seconds (7.3/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 215 seconds (7.3/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:11:43), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:11:43), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:11:43), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 222 seconds (7.3/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 222 seconds (7.3/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 222 seconds (7.3/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:11:50), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:11:50), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:11:50), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 233 seconds (7.4/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 233 seconds (7.4/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 233 seconds (7.4/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:12:00), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:00), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:00), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 238 seconds (7.2/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 238 seconds (7.2/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 2 messages since 238 seconds (7.2/18); in 0 SCW so far; nodes (1): 0 computed 0 restored
# ... mosaic_ii_skyimage : task dependencies delegated : inapplicable
# - waiting for remote response (since 2025-03-15 17:12:05), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:05), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:05), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 247 seconds (7.3/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 247 seconds (7.3/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 247 seconds (7.3/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
# - waiting for remote response (since 2025-03-15 17:12:14), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:14), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:14), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 255 seconds (7.3/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 255 seconds (7.3/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 255 seconds (7.3/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
# - waiting for remote response (since 2025-03-15 17:12:22), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:22), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:22), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 260 seconds (7.2/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 260 seconds (7.2/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 260 seconds (7.2/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
# - waiting for remote response (since 2025-03-15 17:12:28), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:28), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:28), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 268 seconds (7.2/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 268 seconds (7.2/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 268 seconds (7.2/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
# - waiting for remote response (since 2025-03-15 17:12:36), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:36), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:36), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 276 seconds (7.1/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 276 seconds (7.1/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 276 seconds (7.1/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
# - waiting for remote response (since 2025-03-15 17:12:43), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:43), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:43), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 282 seconds (7.1/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 282 seconds (7.1/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  - the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 282 seconds (7.1/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
# - waiting for remote response (since 2025-03-15 17:12:49), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:49), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:49), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 290 seconds (7.1/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 290 seconds (7.1/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  \ the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 290 seconds (7.1/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
# - waiting for remote response (since 2025-03-15 17:12:58), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:58), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:12:58), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 296 seconds (7/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 296 seconds (7/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  | the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 296 seconds (7/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
# - waiting for remote response (since 2025-03-15 17:13:03), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:13:03), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:13:03), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 307 seconds (7.1/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 307 seconds (7.1/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
#  / the job is working remotely, please wait status=progress job_id=6ce2c075 in 3 messages since 307 seconds (7.1/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... ISGRIImagePack : task complete : 066600680010.001
# - waiting for remote response (since 2025-03-15 17:13:14), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:13:14), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:13:14), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#
# ... query status progress => ready
#
# ... query status progress => ready
#
# ... query status progress => ready
#  - the job is working remotely, please wait status=ready job_id=6ce2c075 in 4 messages since 319 seconds (7.2/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... mosaic_ii_skyimage : task complete : inapplicable
#  - the job is working remotely, please wait status=ready job_id=6ce2c075 in 4 messages since 319 seconds (7.2/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... mosaic_ii_skyimage : task complete : inapplicable
#  - the job is working remotely, please wait status=ready job_id=6ce2c075 in 4 messages since 319 seconds (7.2/18); in 1 SCW so far; nodes (2): 0 computed 0 restored
# ... mosaic_ii_skyimage : task complete : inapplicable
# - waiting for remote response (since 2025-03-15 17:13:26), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:13:26), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# - waiting for remote response (since 2025-03-15 17:13:26), please wait for https://www.astro.unige.ch/mmoda/dispatch-data/run_analysis
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
# session: RCFX90DDSMVSNAXK job: 6ce2c0755e724142
#
# ... query status ready => done
#
# ... query status ready => done
#
# ... query status ready => done
# query COMPLETED SUCCESSFULLY (state done)
# query COMPLETED SUCCESSFULLY (state done)
# query COMPLETED SUCCESSFULLY (state done)
# query complete: terminating
# query complete: terminating
# query complete: terminating
# ID=0 prod_name=mosaic_image_0_mosaic  meta_data: {'product': 'mosaic', 'instrument': 'isgri', 'src_name': '', 'query_parameters': None}
#
# ID=1 prod_name=dispatcher_catalog_1  meta_data:

# %% [markdown]
# ## IMAGING & ANALYSIS

# %% [markdown]
# Image analysis (extraction of count rates over time).

# %%
data_collection.mosaic_image_0_mosaic.show()
print(data_collection.mosaic_image_0_mosaic.show_meta())
data_collection.dispatcher_catalog_1.table
# Out:
# ------------------------------
# name: mosaic_image
# meta_data dict_keys(['product', 'instrument', 'src_name', 'query_parameters'])
# number of data units 6
# ------------------------------
# data uniti 0 ,name: PRIMARY
# data uniti 1 ,name: GROUPING
# data uniti 2 ,name: ISGR-MOSA-IMA
# data uniti 3 ,name: ISGR-MOSA-IMA
# data uniti 4 ,name: ISGR-MOSA-IMA
# data uniti 5 ,name: ISGR-MOSA-IMA
# ------------------------------
# product : mosaic
# instrument : isgri
# src_name :
# query_parameters : None
# ------------------------------
# None
# <Table length=1>
# meta_ID src_names    significance   ... ISGRI_FLAG  FLAG        ERR_RAD
#                                     ...
#  int64     str4        float64      ...   int64    int64        float64
# ------- --------- ----------------- ... ---------- ----- ---------------------
#      11      Crab 147.2145538330078 ...          2     0 0.0002800000074785203

# %%
im=OdaImage(data_collection)
_ = im.show()
im.write_fits(f"../data/Crab-{scw_pick}")
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATEREF to '2000-01-01' from MJDREF.
# Set MJD-OBS to 54554.169560 from DATE-OBS.
# Set MJD-END to 54554.191979 from DATE-END'. [astropy.wcs.wcs]
# /home/hthums/micromamba/envs/jupiter_xray/lib/python3.9/site-packages/oda_api/plot_tools.py:101: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# './../data/Crab-066600680010.001mosaic.fits'

# %%
header = data_collection.mosaic_image_0_mosaic.get_data_unit(2).header
header
# Out:
# {'BASETYPE': 'DAL_ARRAY',
#  'BITPIX': -32,
#  'BSCALE': 1,
#  'BUNIT': 'counts/sec',
#  'BZERO': 0,
#  'CD1_1': -0.0822862539155913,
#  'CD1_2': 0.0,
#  'CD2_1': 0.0,
#  'CD2_2': 0.0822862539155913,
#  'CHANMAX': 30,
#  'CHANMIN': 15,
#  'CHANTYPE': 'PI',
#  'CHECKSUM': 'ONbdRKacOKacOKac',
#  'COMMENT': 'STAMP :',
#  'CONFIGUR': 'osa_2021-08-27T14:27:00',
#  'CREATOR': 'ii_skyimage 5.4.4',
#  'CRPIX1': 213.0,
#  'CRPIX2': 213.0,
#  'CRVAL1': 83.8523330688477,
#  'CRVAL2': 26.6662120819092,
#  'CTYPE1': 'RA---TAN',
#  'CTYPE2': 'DEC--TAN',
#  'CUNIT1': 'deg',
#  'CUNIT2': 'deg',
#  'DATASUM': '4009910582',
#  'DATE': '2025-03-15T16:12:45',
#  'DATE-END': '2008-03-29T04:36:27',
#  'DATE-OBS': '2008-03-29T04:04:10',
#  'DEADC': 0.695955381211364,
#  'DETNAM': 'ISGRI',
#  'EQUINOX': 2000.0,
#  'EXTNAME': 'ISGR-MOSA-IMA',
#  'EXTREL': '7.4',
#  'EXTVER': 1,
#  'E_MAX': 30.0,
#  'E_MEAN': 22.5,
#  'E_MIN': 15.0,
#  'GCOUNT': 1,
#  'GRPID1': 1,
#  'HDUCLAS1': 'IMAGE',
#  'HDUCLASS': 'OGIP',
#  'HDUDOC': 'ISDC-IBIS ICD',
#  'HDUVERS': '1.1.0',
#  'IMATYPE': 'INTENSITY',
#  'INSTRUME': 'IBIS',
#  'ISDCLEVL': 'IMA',
#  'LATPOLE': 0,
#  'LONGPOLE': 180,
#  'MJDREF': 51544.0,
#  'MOSASPR': 1,
#  'NAXIS': 2,
#  'NAXIS1': 425,
#  'NAXIS2': 425,
#  'OGID': 'String',
#  'ONTIME': 1683.38000488281,
#  'ORIGIN': 'ISDC',
#  'PCOUNT': 0,
#  'RADECSYS': 'FK5',
#  'STAMP': '2025-03-15T16:12:45 ii_skyimage 5.4.4',
#  'TELAPSE': 1733.0,
#  'TELESCOP': 'INTEGRAL',
#  'TFIRST': 3010.17078918943,
#  'TIMEREF': 'LOCAL',
#  'TIMESYS': 'TT',
#  'TIMEUNIT': 'd',
#  'TLAST': 3010.19085849821,
#  'TSTART': 3010.17031697769,
#  'TSTOP': 3010.19273597254,
#  'XTENSION': 'IMAGE'}

# %%
data_unit = data_collection.mosaic_image_0_mosaic.get_data_unit(2)  
header = data_collection.mosaic_image_0_mosaic.get_data_unit(2).header
image_data = data_unit.data 
wcs = WCS(header)
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATEREF to '2000-01-01' from MJDREF.
# Set MJD-OBS to 54554.169560 from DATE-OBS.
# Set MJD-END to 54554.191979 from DATE-END'. [astropy.wcs.wcs]

# %%
E0 = 100 # 100 keV reference energy
K = 6.2e-4 # flux @ 100 keV (photons/cm2/s), roughly the same for each instrument
E = np.linspace(15, 30)
gamma = 2.12 # photon index of ISGRI (2.105 for SPI+ISGRI+JEM-X)

power_law = K * (E/E0)**(-gamma) # flux

x, y = wcs.all_world2pix(ra, dec, 0)
x_int, y_int = int(round(x.item())), int(round(y.item()))

crab_countrate = image_data[y_int, x_int]

print("Crab count rate:", crab_countrate, "counts/sec")

ph_flux = - K * (E0)**(gamma) / (gamma-1) * ((30)**(1-gamma) - (15)**(1-gamma)) # analytic
ph_flux_num = np.trapz(power_law, E) # numeric
ph_flux_num_erg = np.trapz(power_law*E*1.60218e-9, E) # numeric, energy units

print(f'Analytically calculated photon flux: {ph_flux} ph/cm2/s')
print(f'Numerically calculated photon flux: {ph_flux_num} ph/cm2/s')
print(f'Numerically calculated energy flux: {ph_flux_num_erg} erg/cm2/s')
print(f'Flux per count = energy per photon: {ph_flux_num_erg/ph_flux_num} erg/photon')
print('\nTo convert countrate to flux, multiply countrate by flux per count:',
      f'\nConversion factor: {ph_flux_num/crab_countrate} for ph/cm2/s or {ph_flux_num_erg/crab_countrate} for erg/cm2/s')

plt.figure()
plt.loglog(E, power_law)
plt.xlabel('E ($keV$)')
plt.ylabel('Flux ($ph.cm^{-2}.s^{-1}/keV$)')
# Out:
# Crab count rate: 167.69402 counts/sec
# Analytically calculated photon flux: 0.2501898870399915 ph/cm2/s
# Numerically calculated photon flux: 0.2502236796064092 ph/cm2/s
# Numerically calculated energy flux: 8.296223349642631e-09 erg/cm2/s
# Flux per count = energy per photon: 3.315522880445298e-08 erg/photon
#
# To convert countrate to flux, multiply countrate by flux per count:
# Conversion factor: 0.0014921443610015866 for ph/cm2/s or 4.947238769828189e-11 for erg/cm2/s
# Text(0, 0.5, 'Flux ($ph.cm^{-2}.s^{-1}/keV$)')

# %% [markdown]
# Plot from fits file.

# %%
fits_file = f"../data/Crab-{scw_pick}"+"mosaic.fits"

pick = 2  # 2 for image, 3 for variance, 4 for significance and 5 for exposure map

with fits.open(fits_file) as hdul:
    hdul.info()
    intensity_data = hdul[2].data 
    variance_data = hdul[3].data
    significance_data = hdul[4].data
    exposure_data = hdul[5].data
    #print("\n")
    #print(repr(hdul[pick].header))
    #print("\n")
    #print(hdul[1].data.columns)
    wcs = WCS(hdul[pick].header)  
    CD1 = np.abs(hdul[pick].header["CD1_1"])

data = [intensity_data, variance_data, significance_data, exposure_data]
image_data = data[pick-2]


fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection=wcs)
im = ax.imshow(np.log10(image_data), cmap='plasma', origin='lower', aspect='auto')

ax.set_xlabel('RA')
ax.set_ylabel('DEC')

x, y = wcs.all_world2pix(ra, dec, 0)

pixel_scale = CD1 * 3600  # pixel size in arcseconds (|CD1_1| from fits header)
circle_radius_pixels = 7 * 60 / pixel_scale / 2 

circle = Circle((x, y), circle_radius_pixels, edgecolor='black', facecolor='none', lw = 0.5)
ax.add_patch(circle)

ax.annotate(
        text="Crab", 
        xy=(x, y),  
        xytext=(x - 100, y + 150),
        arrowprops=dict(arrowstyle="->", color="black", lw=0.5),
        fontsize=11,
        color="black"
    )

title = ""
if pick == 2:
    title = "Intensity"
elif pick == 3:
    title = "Variance"
elif pick == 4:
    title = "Significance"
elif pick == 5:
    title = "Exposure"

plt.title(title+" map")
plt.colorbar(im, label="Intensity")

#plt.savefig(f"../data/Crab-{scw_pick}"+"_"+f"{title}.pdf", format='pdf', bbox_inches='tight')

# %% [markdown]
# Countrate to flux conversion (method of E. Jourdain using ISGRI calibration).

# %%
E0 = 100 # 100 keV reference energy
K = 6.2e-4 # flux @ 100 keV (photons/cm2/s), roughly the same for each instrument
E = np.linspace(15, 30)
gamma = 2.12 # photon index of ISGRI (2.105 for SPI+ISGRI+JEM-X)

power_law = K * (E/E0)**(-gamma) # flux

x_int, y_int = int(round(x.item())), int(round(y.item()))

crab_countrate = intensity_data[y_int, x_int]

print("Crab count rate:", crab_countrate, "counts/sec")

ph_flux = - K * (E0)**(gamma) / (gamma-1) * ((30)**(1-gamma) - (15)**(1-gamma)) # analytic
ph_flux_num = np.trapz(power_law, E) # numeric
ph_flux_num_erg = np.trapz(power_law*E*1.60218e-9, E) # numeric, energy units

print(f'Analytically calculated photon flux: {ph_flux} ph/cm2/s')
print(f'Numerically calculated photon flux: {ph_flux_num} ph/cm2/s')
print(f'Numerically calculated energy flux: {ph_flux_num_erg} erg/cm2/s')
print(f'Flux per count = energy per photon: {ph_flux_num_erg/ph_flux_num} erg/photon')
print('\nTo convert countrate to flux, multiply countrate by flux per count:',
      f'\nConversion factor: {ph_flux_num/crab_countrate} for ph/cm2/s or {ph_flux_num_erg/crab_countrate} for erg/cm2/s')

plt.figure()
plt.loglog(E, power_law)
plt.xlabel('E ($keV$)')
plt.ylabel('Flux ($ph.cm^{-2}.s^{-1}/keV$)')
# Out:
# Crab count rate: 167.69402 counts/sec
# Analytically calculated photon flux: 0.2501898870399915 ph/cm2/s
# Numerically calculated photon flux: 0.2502236796064092 ph/cm2/s
# Numerically calculated energy flux: 8.296223349642631e-09 erg/cm2/s
# Flux per count = energy per photon: 3.315522880445298e-08 erg/photon
#
# To convert countrate to flux, multiply countrate by flux per count:
# Conversion factor: 0.0014921443610015866 for ph/cm2/s or 4.947238769828189e-11 for erg/cm2/s
# Text(0, 0.5, 'Flux ($ph.cm^{-2}.s^{-1}/keV$)')
